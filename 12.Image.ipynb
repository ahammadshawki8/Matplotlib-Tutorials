# %%
# module 12
# working with image in matplotlib

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img=mpimg.imread("F:\Python\\6. Matplotlib\pic\stink bug.jpg")
print(img)
# Out:
# [[[105 105 105]
#   [106 106 106]
#   [106 106 106]
#   ...
#   [110 110 110]
#   [110 110 110]
#   [110 110 110]]
#
#  [[106 106 106]
#   [106 106 106]
#   [107 107 107]
#   ...
#   [110 110 110]
#   [110 110 110]
#   [110 110 110]]
#
#  [[107 107 107]
#   [108 108 108]
#   [108 108 108]
#   ...
#   [112 112 112]
#   [112 112 112]
#   [112 112 112]]
#
#  ...
#
#  [[109 109 109]
#   [109 109 109]
#   [110 110 110]
#   ...
#   [117 117 117]
#   [117 117 117]
#   [117 117 117]]
#
#  [[111 111 111]
#   [112 112 112]
#   [112 112 112]
#   ...
#   [115 115 115]
#   [115 115 115]
#   [115 115 115]]
#
#  [[111 111 111]
#   [112 112 112]
#   [112 112 112]
#   ...
#   [115 115 115]
#   [115 115 115]
#   [115 115 115]]]

# %%
implot=plt.imshow(img)

# %%
lum_img=img[:,:,0]
implot=plt.imshow(lum_img)

# %%
impolt=plt.imshow(lum_img,cmap="hot")

# %%
plt.imshow(lum_img,cmap="nipy_spectral")

# %%
plt.imshow(lum_img,cmap="nipy_spectral")
cbar=plt.colorbar()
cbar.set_label("Color Scale")

# %%
plt.hist(lum_img.flatten(), bins=256, range=(0.0, 1.0), fc='k', ec='k')
plt.show()

# %%
plt.imshow(lum_img,clim=(1.0))

# %%
plt.hist(img2,bins=256,range=(0.0,1.0))
plt.show()

# %%
fig = plt.figure()

a = fig.add_subplot(1, 2, 1)
imgplot = plt.imshow(lum_img)
a.set_title('Before')

plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')

a = fig.add_subplot(1, 2, 2)
imgplot = plt.imshow(lum_img)
imgplot.set_clim(1.0)
a.set_title('After')
plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')

# %%
from PIL import Image
img=Image.open("F:\Python\\6. Matplotlib\pic\stink bug.jpg")
img.thumbnail((64,64), Image.ANTIALIAS) # resizes image in place
implot=plt.imshow(img)

# %%
implot=plt.imshow(img,interpolation="nearest")

# %%
implot=plt.imshow(img,interpolation="bicubic")
